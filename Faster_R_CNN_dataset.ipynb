# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.3)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 28.6 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.4.3

# %%
import numpy as np
import rasterio
from rasterio.windows import Window
from rasterio.windows import bounds
import glob
import os
import pyproj
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import sys
import time
import math
import zipfile
import random
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
brick_coords='/content/all_kilns_dec102024.xlsx'
coords_df = pd.read_excel(brick_coords)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell N3356 is marked as a date but the serial value 10999311 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)

# %%
coords_df.columns
# Out:
# Index(['uid', 'Latitude', 'Longitude', 'Type', 'Active', 'Boyd22',
#        'stanford21', 'gob17_18', 'Type_correct', 'first_inactive',
#        'last_active', 'first_start', 'last_before_start', 'fck_to_zzk',
#        'zzk_to_fck', 'Boyd18', 'Union', 'ADM4_PCODE', 'Upazila', 'ADM3_PCODE',
#        'District', 'ADM2_PCODE', 'Division'],
#       dtype='object')

# %%
zip_path = '/content/S2B_MSIL2A_20250405T042659_N0511_R133_T46QBM_20250405T063356.SAFE.zip'

extract_path = '/content/extracted_data'

if not os.path.exists(extract_path):
    os.makedirs(extract_path)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"Extraction complete. Files are extracted to: {extract_path}")
# Out:
# Extraction complete. Files are extracted to: /content/extracted_data

# %%
BRICK_COORDS = Path('/content/all_kilns_dec102024.xlsx')
SAFE_DIR     = Path('/content/extracted_data'
                     '/S2B_MSIL2A_20250405T042659_N0511_R133_T46QBM_20250405T063356.SAFE')
OUTPUT_DIR   = Path('kiln_dataset_v2')
PATCH_SUBDIR = 'images'
LABELS_FILE  = 'labels.csv'

IMAGE_RES_M  = 10.0
SCALE_FACTOR = 10_000.0
KILN_DIAM_M  = 66.0
PATCH_PX     = 64
NEG_PER_POS  = 1
RNG_SEED     = 42

kiln_px = math.ceil(KILN_DIAM_M / IMAGE_RES_M)
if kiln_px % 2 == 0:
    kiln_px += 1
EST_KILN_PX = kiln_px
HALF_PATCH  = PATCH_PX // 2

patches_dir = OUTPUT_DIR / PATCH_SUBDIR
patches_dir.mkdir(parents=True, exist_ok=True)

print("––– Configuration –––")
print(f" coords file:   {BRICK_COORDS}")
print(f" SAFE dir:      {SAFE_DIR}")
print(f" output patches:{patches_dir}")
print(f" patch size:    {PATCH_PX} px")
print(f" kiln box:      {EST_KILN_PX} px")
print("––––––––––––––––––––––\n")


def overlaps_any_kiln(tile_row: int, tile_col: int, kiln_rc: np.ndarray) -> bool:
    """Return *True* if a 128 px tile intersects any kiln bounding box."""
    tile_bottom = tile_row + PATCH_PX - 1
    tile_right  = tile_col + PATCH_PX - 1
    r = kiln_rc[:, 0]
    c = kiln_rc[:, 1]
    hk = EST_KILN_PX // 2
    inside = (
        (r >= tile_row   - hk) & (r <= tile_bottom + hk) &
        (c >= tile_col   - hk) & (c <= tile_right  + hk)
    )
    return bool(inside.any())


def read_rgb_window(srcs: list[rasterio.io.DatasetReader], win: Window) -> np.ndarray:
    """Read bands 1–3 over *win* and return float32 array in [0,1]."""
    bands = [s.read(1, window=win).astype(np.float32) for s in srcs]
    data  = np.stack(bands, axis=-1) / SCALE_FACTOR
    return np.clip(data, 0, 1)


coords_df = pd.read_excel(BRICK_COORDS)
if not {"Latitude", "Longitude"}.issubset(coords_df.columns):
    raise ValueError("Excel file must contain 'Latitude' and 'Longitude' columns")
print(f"Loaded {len(coords_df)} kiln coordinates from Excel")

band_glob  = SAFE_DIR / 'GRANULE' / '*' / 'IMG_DATA' / 'R10m'
band_pats  = ['*_B04_10m.jp2', '*_B03_10m.jp2', '*_B02_10m.jp2']  # R, G, B
band_paths = [glob.glob(str(band_glob / pat))[0] for pat in band_pats]

srcs       = [rasterio.open(p) for p in band_paths]
transform  = srcs[0].transform
crs        = srcs[0].crs
width, height = srcs[0].width, srcs[0].height
print(f"Image: {width}×{height} px, CRS={crs.to_string()}")

wgs84   = pyproj.CRS('EPSG:4326')
img_crs = pyproj.CRS(crs)
proj    = pyproj.Transformer.from_crs(wgs84, img_crs, always_xy=True)

xs, ys = proj.transform(coords_df['Longitude'].to_numpy(),
                        coords_df['Latitude'].to_numpy())
rows, cols = rasterio.transform.rowcol(transform, xs, ys)
coords_df['pixel_row'] = rows
coords_df['pixel_col'] = cols
kiln_rc = coords_df[['pixel_row', 'pixel_col']].to_numpy()

labels: list[dict] = []
start_time = time.time()

pos_written = 0
for _, row in coords_df.iterrows():
    pr, pc = int(row['pixel_row']), int(row['pixel_col'])

    if pr < 0 or pc < 0 or pr >= height or pc >= width:
        continue

    tile_row = (pr // PATCH_PX) * PATCH_PX
    tile_col = (pc // PATCH_PX) * PATCH_PX
    win      = Window(tile_col, tile_row, PATCH_PX, PATCH_PX)

    patch = read_rgb_window(srcs, win)
    out_name = f"kiln_{pos_written+1:04d}_patch.tif"
    print(f"Saved {out_name} (bbox [{xmin},{ymin}]→[{xmax},{ymax}])")

    pos_written += 1
    pr, pc = int(row['pixel_row']), int(row['pixel_col'])

    if pr < 0 or pc < 0 or pr >= height or pc >= width:
        continue

    tile_row = (pr // PATCH_PX) * PATCH_PX
    tile_col = (pc // PATCH_PX) * PATCH_PX
    win      = Window(tile_col, tile_row, PATCH_PX, PATCH_PX)

    patch = read_rgb_window(srcs, win)

    out_name = f"kiln_{pos_written+1:04d}_patch.tif"
    out_path = patches_dir / out_name

    profile = srcs[0].profile.copy()
    profile.update(
        driver='GTiff', height=PATCH_PX, width=PATCH_PX,
        count=3, dtype=patch.dtype,
        transform=rasterio.windows.transform(win, transform)
    )
    for k in ('nodata', 'tiled', 'blockxsize', 'blockysize', 'compress', 'interleave'):
        profile.pop(k, None)

    with rasterio.open(out_path, 'w', **profile) as dst:
        dst.write(np.moveaxis(patch, -1, 0))

    hk   = EST_KILN_PX // 2
    cx   = pc - tile_col
    cy   = pr - tile_row
    xmin = max(0, cx - hk)
    ymin = max(0, cy - hk)
    xmax = min(PATCH_PX - 1, cx + hk)
    ymax = min(PATCH_PX - 1, cy + hk)

    labels.append(dict(
        filename=os.path.join(PATCH_SUBDIR, out_name),
        width=PATCH_PX, height=PATCH_PX, clazz='kiln',
        xmin=xmin, ymin=ymin, xmax=xmax, ymax=ymax
    ))

    pos_written += 1
    print(f"Saved {out_name} (bbox [{xmin},{ymin}]→[{xmax},{ymax}])")


neg_needed = pos_written
rng        = np.random.default_rng(RNG_SEED)
neg_written = 0

while neg_written < neg_needed:
    tile_row = int(rng.integers(0, height // PATCH_PX) * PATCH_PX)
    tile_col = int(rng.integers(0, width  // PATCH_PX) * PATCH_PX)

    if overlaps_any_kiln(tile_row, tile_col, kiln_rc):
        continue  # skip tiles that touch a kiln

    win   = Window(tile_col, tile_row, PATCH_PX, PATCH_PX)
    patch = read_rgb_window(srcs, win)

    out_name = f"background_{neg_written+1:04d}_patch.tif"
    out_path = patches_dir / out_name

    profile = srcs[0].profile.copy()
    profile.update(
        driver='GTiff', height=PATCH_PX, width=PATCH_PX,
        count=3, dtype=patch.dtype,
        transform=rasterio.windows.transform(win, transform)
    )
    for k in ('nodata', 'tiled', 'blockxsize', 'blockysize', 'compress', 'interleave'):
        profile.pop(k, None)

    with rasterio.open(out_path, 'w', **profile) as dst:
        dst.write(np.moveaxis(patch, -1, 0))

    labels.append(dict(
        filename=os.path.join(PATCH_SUBDIR, out_name),
        width=PATCH_PX, height=PATCH_PX, clazz='non_kiln',
        xmin='', ymin='', xmax='', ymax=''
    ))
    neg_written += 1
    print(f"Saved {out_name} (bbox [ ][ ]→[ ][ ])")

for s in srcs:
    s.close()

labels_df = pd.DataFrame(labels)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
labels_df.to_csv(OUTPUT_DIR / LABELS_FILE, index=False)

total_t = time.time() - start_time
print(f"\nFinished {pos_written} kiln + {neg_written} background patches in {total_t:.1f}s")
print(f"Labels saved to {OUTPUT_DIR / LABELS_FILE}\n")
# Out:
# ––– Configuration –––
#  coords file:   /content/all_kilns_dec102024.xlsx
#  SAFE dir:      /content/extracted_data/S2B_MSIL2A_20250405T042659_N0511_R133_T46QBM_20250405T063356.SAFE
#  output patches:kiln_dataset_v2/images
#  patch size:    64 px
#  kiln box:      7 px
#  positives:     20
#  negatives:     20
# ––––––––––––––––––––––
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell N3356 is marked as a date but the serial value 10999311 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# Streaming output truncated to the last 5000 lines.
# Saved kiln_3101_patch.tif (bbox [8,52]→[14,58])
# Saved kiln_3102_patch.tif (bbox [19,47]→[25,53])
# Saved kiln_3103_patch.tif (bbox [19,47]→[25,53])
# Saved kiln_3104_patch.tif (bbox [44,42]→[50,48])
# Saved kiln_3105_patch.tif (bbox [44,42]→[50,48])
# Saved kiln_3106_patch.tif (bbox [17,43]→[23,49])
# Saved kiln_3107_patch.tif (bbox [17,43]→[23,49])
# Saved kiln_3108_patch.tif (bbox [24,33]→[30,39])
# Saved kiln_3109_patch.tif (bbox [24,33]→[30,39])
# Saved kiln_3110_patch.tif (bbox [49,33]→[55,39])
# Saved kiln_3111_patch.tif (bbox [49,33]→[55,39])
# Saved kiln_3112_patch.tif (bbox [60,27]→[63,33])
# Saved kiln_3113_patch.tif (bbox [60,27]→[63,33])
# Saved kiln_3114_patch.tif (bbox [23,3]→[29,9])
# Saved kiln_3115_patch.tif (bbox [23,3]→[29,9])
# Saved kiln_3116_patch.tif (bbox [31,1]→[37,7])
# Saved kiln_3117_patch.tif (bbox [31,1]→[37,7])
# Saved kiln_3118_patch.tif (bbox [29,51]→[35,57])
# Saved kiln_3119_patch.tif (bbox [29,51]→[35,57])
# Saved kiln_3120_patch.tif (bbox [36,47]→[42,53])
# Saved kiln_3121_patch.tif (bbox [36,47]→[42,53])
# Saved kiln_3122_patch.tif (bbox [1,32]→[7,38])
# Saved kiln_3123_patch.tif (bbox [1,32]→[7,38])
# Saved kiln_3124_patch.tif (bbox [31,31]→[37,37])
# Saved kiln_3125_patch.tif (bbox [31,31]→[37,37])
# Saved kiln_3126_patch.tif (bbox [20,0]→[26,4])
# Saved kiln_3127_patch.tif (bbox [20,0]→[26,4])
# Saved kiln_3128_patch.tif (bbox [2,60]→[8,63])
# Saved kiln_3129_patch.tif (bbox [2,60]→[8,63])
# Saved kiln_3130_patch.tif (bbox [34,20]→[40,26])
# Saved kiln_3131_patch.tif (bbox [34,20]→[40,26])
# Saved kiln_3132_patch.tif (bbox [35,12]→[41,18])
# Saved kiln_3133_patch.tif (bbox [35,12]→[41,18])
# Saved kiln_3134_patch.tif (bbox [48,8]→[54,14])
# Saved kiln_3135_patch.tif (bbox [48,8]→[54,14])
# Saved kiln_3136_patch.tif (bbox [33,56]→[39,62])
# Saved kiln_3137_patch.tif (bbox [33,56]→[39,62])
# Saved kiln_3138_patch.tif (bbox [55,54]→[61,60])
# Saved kiln_3139_patch.tif (bbox [55,54]→[61,60])
# Saved kiln_3140_patch.tif (bbox [17,46]→[23,52])
# Saved kiln_3141_patch.tif (bbox [17,46]→[23,52])
# Saved kiln_3142_patch.tif (bbox [30,52]→[36,58])
# Saved kiln_3143_patch.tif (bbox [30,52]→[36,58])
# Saved kiln_3144_patch.tif (bbox [39,50]→[45,56])
# Saved kiln_3145_patch.tif (bbox [39,50]→[45,56])
# Saved kiln_3146_patch.tif (bbox [47,19]→[53,25])
# Saved kiln_3147_patch.tif (bbox [47,19]→[53,25])
# Saved kiln_3148_patch.tif (bbox [25,41]→[31,47])
# Saved kiln_3149_patch.tif (bbox [25,41]→[31,47])
# Saved kiln_3150_patch.tif (bbox [5,33]→[11,39])
# Saved kiln_3151_patch.tif (bbox [5,33]→[11,39])
# Saved kiln_3152_patch.tif (bbox [15,59]→[21,63])
# Saved kiln_3153_patch.tif (bbox [15,59]→[21,63])
# Saved kiln_3154_patch.tif (bbox [34,56]→[40,62])
# Saved kiln_3155_patch.tif (bbox [34,56]→[40,62])
# Saved kiln_3156_patch.tif (bbox [31,41]→[37,47])
# Saved kiln_3157_patch.tif (bbox [31,41]→[37,47])
# Saved kiln_3158_patch.tif (bbox [19,0]→[25,6])
# Saved kiln_3159_patch.tif (bbox [19,0]→[25,6])
# Saved kiln_3160_patch.tif (bbox [37,46]→[43,52])
# Saved kiln_3161_patch.tif (bbox [37,46]→[43,52])
# Saved kiln_3162_patch.tif (bbox [0,45]→[3,51])
# Saved kiln_3163_patch.tif (bbox [0,45]→[3,51])
# Saved kiln_3164_patch.tif (bbox [41,3]→[47,9])
# Saved kiln_3165_patch.tif (bbox [41,3]→[47,9])
# Saved kiln_3166_patch.tif (bbox [49,33]→[55,39])
# Saved kiln_3167_patch.tif (bbox [49,33]→[55,39])
# Saved kiln_3168_patch.tif (bbox [9,35]→[15,41])
# Saved kiln_3169_patch.tif (bbox [9,35]→[15,41])
# Saved kiln_3170_patch.tif (bbox [47,10]→[53,16])
# Saved kiln_3171_patch.tif (bbox [47,10]→[53,16])
# Saved kiln_3172_patch.tif (bbox [58,50]→[63,56])
# Saved kiln_3173_patch.tif (bbox [58,50]→[63,56])
# Saved kiln_3174_patch.tif (bbox [47,2]→[53,8])
# Saved kiln_3175_patch.tif (bbox [47,2]→[53,8])
# Saved kiln_3176_patch.tif (bbox [9,50]→[15,56])
# Saved kiln_3177_patch.tif (bbox [9,50]→[15,56])
# Saved kiln_3178_patch.tif (bbox [11,10]→[17,16])
# Saved kiln_3179_patch.tif (bbox [11,10]→[17,16])
# Saved kiln_3180_patch.tif (bbox [0,18]→[5,24])
# Saved kiln_3181_patch.tif (bbox [0,18]→[5,24])
# Saved kiln_3182_patch.tif (bbox [16,6]→[22,12])
# Saved kiln_3183_patch.tif (bbox [16,6]→[22,12])
# Saved kiln_3184_patch.tif (bbox [11,50]→[17,56])
# Saved kiln_3185_patch.tif (bbox [11,50]→[17,56])
# Saved kiln_3186_patch.tif (bbox [7,20]→[13,26])
# Saved kiln_3187_patch.tif (bbox [7,20]→[13,26])
# Saved kiln_3188_patch.tif (bbox [53,16]→[59,22])
# Saved kiln_3189_patch.tif (bbox [53,16]→[59,22])
# Saved kiln_3190_patch.tif (bbox [50,58]→[56,63])
# Saved kiln_3191_patch.tif (bbox [50,58]→[56,63])
# Saved kiln_3192_patch.tif (bbox [51,1]→[57,7])
# Saved kiln_3193_patch.tif (bbox [51,1]→[57,7])
# Saved kiln_3194_patch.tif (bbox [39,12]→[45,18])
# Saved kiln_3195_patch.tif (bbox [39,12]→[45,18])
# Saved kiln_3196_patch.tif (bbox [34,58]→[40,63])
# Saved kiln_3197_patch.tif (bbox [34,58]→[40,63])
# Saved kiln_3198_patch.tif (bbox [14,40]→[20,46])
# Saved kiln_3199_patch.tif (bbox [14,40]→[20,46])
# Saved kiln_3200_patch.tif (bbox [59,52]→[63,58])
# Saved kiln_3201_patch.tif (bbox [59,52]→[63,58])
# Saved kiln_3202_patch.tif (bbox [0,27]→[4,33])
# Saved kiln_3203_patch.tif (bbox [0,27]→[4,33])
# Saved kiln_3204_patch.tif (bbox [0,35]→[6,41])
# Saved kiln_3205_patch.tif (bbox [0,35]→[6,41])
# Saved kiln_3206_patch.tif (bbox [0,25]→[5,31])
# Saved kiln_3207_patch.tif (bbox [0,25]→[5,31])
# Saved kiln_3208_patch.tif (bbox [58,18]→[63,24])
# Saved kiln_3209_patch.tif (bbox [58,18]→[63,24])
# Saved kiln_3210_patch.tif (bbox [25,16]→[31,22])
# Saved kiln_3211_patch.tif (bbox [25,16]→[31,22])
# Saved kiln_3212_patch.tif (bbox [0,58]→[5,63])
# Saved kiln_3213_patch.tif (bbox [0,58]→[5,63])
# Saved kiln_3214_patch.tif (bbox [38,14]→[44,20])
# Saved kiln_3215_patch.tif (bbox [38,14]→[44,20])
# Saved kiln_3216_patch.tif (bbox [33,0]→[39,6])
# Saved kiln_3217_patch.tif (bbox [33,0]→[39,6])
# Saved kiln_3218_patch.tif (bbox [10,0]→[16,3])
# Saved kiln_3219_patch.tif (bbox [10,0]→[16,3])
# Saved kiln_3220_patch.tif (bbox [48,58]→[54,63])
# Saved kiln_3221_patch.tif (bbox [48,58]→[54,63])
# Saved kiln_3222_patch.tif (bbox [36,30]→[42,36])
# Saved kiln_3223_patch.tif (bbox [36,30]→[42,36])
# Saved kiln_3224_patch.tif (bbox [27,50]→[33,56])
# Saved kiln_3225_patch.tif (bbox [27,50]→[33,56])
# Saved kiln_3226_patch.tif (bbox [29,59]→[35,63])
# Saved kiln_3227_patch.tif (bbox [29,59]→[35,63])
# Saved kiln_3228_patch.tif (bbox [3,4]→[9,10])
# Saved kiln_3229_patch.tif (bbox [3,4]→[9,10])
# Saved kiln_3230_patch.tif (bbox [17,52]→[23,58])
# Saved kiln_3231_patch.tif (bbox [17,52]→[23,58])
# Saved kiln_3232_patch.tif (bbox [30,0]→[36,3])
# Saved kiln_3233_patch.tif (bbox [30,0]→[36,3])
# Saved kiln_3234_patch.tif (bbox [55,58]→[61,63])
# Saved kiln_3235_patch.tif (bbox [55,58]→[61,63])
# Saved kiln_3236_patch.tif (bbox [40,26]→[46,32])
# Saved kiln_3237_patch.tif (bbox [40,26]→[46,32])
# Saved kiln_3238_patch.tif (bbox [54,50]→[60,56])
# Saved kiln_3239_patch.tif (bbox [54,50]→[60,56])
# Saved kiln_3240_patch.tif (bbox [30,45]→[36,51])
# Saved kiln_3241_patch.tif (bbox [30,45]→[36,51])
# Saved kiln_3242_patch.tif (bbox [43,10]→[49,16])
# Saved kiln_3243_patch.tif (bbox [43,10]→[49,16])
# Saved kiln_3244_patch.tif (bbox [9,32]→[15,38])
# Saved kiln_3245_patch.tif (bbox [9,32]→[15,38])
# Saved kiln_3246_patch.tif (bbox [22,17]→[28,23])
# Saved kiln_3247_patch.tif (bbox [22,17]→[28,23])
# Saved kiln_3248_patch.tif (bbox [1,0]→[7,5])
# Saved kiln_3249_patch.tif (bbox [1,0]→[7,5])
# Saved kiln_3250_patch.tif (bbox [32,39]→[38,45])
# Saved kiln_3251_patch.tif (bbox [32,39]→[38,45])
# Saved kiln_3252_patch.tif (bbox [57,33]→[63,39])
# Saved kiln_3253_patch.tif (bbox [57,33]→[63,39])
# Saved kiln_3254_patch.tif (bbox [48,49]→[54,55])
# Saved kiln_3255_patch.tif (bbox [48,49]→[54,55])
# Saved kiln_3256_patch.tif (bbox [37,51]→[43,57])
# Saved kiln_3257_patch.tif (bbox [37,51]→[43,57])
# Saved kiln_3258_patch.tif (bbox [38,8]→[44,14])
# Saved kiln_3259_patch.tif (bbox [38,8]→[44,14])
# Saved kiln_3260_patch.tif (bbox [44,17]→[50,23])
# Saved kiln_3261_patch.tif (bbox [44,17]→[50,23])
# Saved kiln_3262_patch.tif (bbox [55,59]→[61,63])
# Saved kiln_3263_patch.tif (bbox [55,59]→[61,63])
# Saved kiln_3264_patch.tif (bbox [41,15]→[47,21])
# Saved kiln_3265_patch.tif (bbox [41,15]→[47,21])
# Saved kiln_3266_patch.tif (bbox [29,1]→[35,7])
# Saved kiln_3267_patch.tif (bbox [29,1]→[35,7])
# Saved kiln_3268_patch.tif (bbox [33,21]→[39,27])
# Saved kiln_3269_patch.tif (bbox [33,21]→[39,27])
# Saved kiln_3270_patch.tif (bbox [10,39]→[16,45])
# Saved kiln_3271_patch.tif (bbox [10,39]→[16,45])
# Saved kiln_3272_patch.tif (bbox [20,14]→[26,20])
# Saved kiln_3273_patch.tif (bbox [20,14]→[26,20])
# Saved kiln_3274_patch.tif (bbox [15,40]→[21,46])
# Saved kiln_3275_patch.tif (bbox [15,40]→[21,46])
# Saved kiln_3276_patch.tif (bbox [25,4]→[31,10])
# Saved kiln_3277_patch.tif (bbox [25,4]→[31,10])
# Saved kiln_3278_patch.tif (bbox [12,28]→[18,34])
# Saved kiln_3279_patch.tif (bbox [12,28]→[18,34])
# Saved kiln_3280_patch.tif (bbox [43,0]→[49,3])
# Saved kiln_3281_patch.tif (bbox [43,0]→[49,3])
# Saved kiln_3282_patch.tif (bbox [34,18]→[40,24])
# Saved kiln_3283_patch.tif (bbox [34,18]→[40,24])
# Saved kiln_3284_patch.tif (bbox [1,14]→[7,20])
# Saved kiln_3285_patch.tif (bbox [1,14]→[7,20])
# Saved kiln_3286_patch.tif (bbox [22,9]→[28,15])
# Saved kiln_3287_patch.tif (bbox [22,9]→[28,15])
# Saved kiln_3288_patch.tif (bbox [27,4]→[33,10])
# Saved kiln_3289_patch.tif (bbox [27,4]→[33,10])
# Saved kiln_3290_patch.tif (bbox [40,33]→[46,39])
# Saved kiln_3291_patch.tif (bbox [40,33]→[46,39])
# Saved kiln_3292_patch.tif (bbox [21,29]→[27,35])
# Saved kiln_3293_patch.tif (bbox [21,29]→[27,35])
# Saved kiln_3294_patch.tif (bbox [8,28]→[14,34])
# Saved kiln_3295_patch.tif (bbox [8,28]→[14,34])
# Saved kiln_3296_patch.tif (bbox [1,5]→[7,11])
# Saved kiln_3297_patch.tif (bbox [1,5]→[7,11])
# Saved kiln_3298_patch.tif (bbox [48,50]→[54,56])
# Saved kiln_3299_patch.tif (bbox [48,50]→[54,56])
# Saved kiln_3300_patch.tif (bbox [32,41]→[38,47])
# Saved kiln_3301_patch.tif (bbox [32,41]→[38,47])
# Saved kiln_3302_patch.tif (bbox [55,37]→[61,43])
# Saved kiln_3303_patch.tif (bbox [55,37]→[61,43])
# Saved kiln_3304_patch.tif (bbox [49,54]→[55,60])
# Saved kiln_3305_patch.tif (bbox [49,54]→[55,60])
# Saved kiln_3306_patch.tif (bbox [28,14]→[34,20])
# Saved kiln_3307_patch.tif (bbox [28,14]→[34,20])
# Saved kiln_3308_patch.tif (bbox [36,5]→[42,11])
# Saved kiln_3309_patch.tif (bbox [36,5]→[42,11])
# Saved kiln_3310_patch.tif (bbox [24,2]→[30,8])
# Saved kiln_3311_patch.tif (bbox [24,2]→[30,8])
# Saved kiln_3312_patch.tif (bbox [5,58]→[11,63])
# Saved kiln_3313_patch.tif (bbox [5,58]→[11,63])
# Saved kiln_3314_patch.tif (bbox [37,53]→[43,59])
# Saved kiln_3315_patch.tif (bbox [37,53]→[43,59])
# Saved kiln_3316_patch.tif (bbox [22,38]→[28,44])
# Saved kiln_3317_patch.tif (bbox [22,38]→[28,44])
# Saved kiln_3318_patch.tif (bbox [50,36]→[56,42])
# Saved kiln_3319_patch.tif (bbox [50,36]→[56,42])
# Saved kiln_3320_patch.tif (bbox [56,21]→[62,27])
# Saved kiln_3321_patch.tif (bbox [56,21]→[62,27])
# Saved kiln_3322_patch.tif (bbox [28,4]→[34,10])
# Saved kiln_3323_patch.tif (bbox [28,4]→[34,10])
# Saved kiln_3324_patch.tif (bbox [18,5]→[24,11])
# Saved kiln_3325_patch.tif (bbox [18,5]→[24,11])
# Saved kiln_3326_patch.tif (bbox [40,5]→[46,11])
# Saved kiln_3327_patch.tif (bbox [40,5]→[46,11])
# Saved kiln_3328_patch.tif (bbox [26,6]→[32,12])
# Saved kiln_3329_patch.tif (bbox [26,6]→[32,12])
# Saved kiln_3330_patch.tif (bbox [31,2]→[37,8])
# Saved kiln_3331_patch.tif (bbox [31,2]→[37,8])
# Saved kiln_3332_patch.tif (bbox [30,30]→[36,36])
# Saved kiln_3333_patch.tif (bbox [30,30]→[36,36])
# Saved kiln_3334_patch.tif (bbox [2,38]→[8,44])
# Saved kiln_3335_patch.tif (bbox [2,38]→[8,44])
# Saved kiln_3336_patch.tif (bbox [9,4]→[15,10])
# Saved kiln_3337_patch.tif (bbox [9,4]→[15,10])
# Saved kiln_3338_patch.tif (bbox [6,44]→[12,50])
# Saved kiln_3339_patch.tif (bbox [6,44]→[12,50])
# Saved kiln_3340_patch.tif (bbox [7,3]→[13,9])
# Saved kiln_3341_patch.tif (bbox [7,3]→[13,9])
# Saved kiln_3342_patch.tif (bbox [9,44]→[15,50])
# Saved kiln_3343_patch.tif (bbox [9,44]→[15,50])
# Saved kiln_3344_patch.tif (bbox [59,40]→[63,46])
# Saved kiln_3345_patch.tif (bbox [59,40]→[63,46])
# Saved kiln_3346_patch.tif (bbox [51,52]→[57,58])
# Saved kiln_3347_patch.tif (bbox [51,52]→[57,58])
# Saved kiln_3348_patch.tif (bbox [24,10]→[30,16])
# Saved kiln_3349_patch.tif (bbox [24,10]→[30,16])
# Saved kiln_3350_patch.tif (bbox [58,3]→[63,9])
# Saved kiln_3351_patch.tif (bbox [58,3]→[63,9])
# Saved kiln_3352_patch.tif (bbox [31,20]→[37,26])
# Saved kiln_3353_patch.tif (bbox [31,20]→[37,26])
# Saved kiln_3354_patch.tif (bbox [55,3]→[61,9])
# Saved kiln_3355_patch.tif (bbox [55,3]→[61,9])
# Saved kiln_3356_patch.tif (bbox [25,47]→[31,53])
# Saved kiln_3357_patch.tif (bbox [25,47]→[31,53])
# Saved kiln_3358_patch.tif (bbox [56,10]→[62,16])
# Saved kiln_3359_patch.tif (bbox [56,10]→[62,16])
# Saved kiln_3360_patch.tif (bbox [53,55]→[59,61])
# Saved kiln_3361_patch.tif (bbox [53,55]→[59,61])
# Saved kiln_3362_patch.tif (bbox [28,49]→[34,55])
# Saved kiln_3363_patch.tif (bbox [28,49]→[34,55])
# Saved kiln_3364_patch.tif (bbox [56,56]→[62,62])
# Saved kiln_3365_patch.tif (bbox [56,56]→[62,62])
# Saved kiln_3366_patch.tif (bbox [46,59]→[52,63])
# Saved kiln_3367_patch.tif (bbox [46,59]→[52,63])
# Saved kiln_3368_patch.tif (bbox [50,9]→[56,15])
# Saved kiln_3369_patch.tif (bbox [50,9]→[56,15])
# Saved kiln_3370_patch.tif (bbox [31,36]→[37,42])
# Saved kiln_3371_patch.tif (bbox [31,36]→[37,42])
# Saved kiln_3372_patch.tif (bbox [24,26]→[30,32])
# Saved kiln_3373_patch.tif (bbox [24,26]→[30,32])
# Saved kiln_3374_patch.tif (bbox [58,14]→[63,20])
# Saved kiln_3375_patch.tif (bbox [58,14]→[63,20])
# Saved kiln_3376_patch.tif (bbox [18,11]→[24,17])
# Saved kiln_3377_patch.tif (bbox [18,11]→[24,17])
# Saved kiln_3378_patch.tif (bbox [0,23]→[4,29])
# Saved kiln_3379_patch.tif (bbox [0,23]→[4,29])
# Saved kiln_3380_patch.tif (bbox [22,20]→[28,26])
# Saved kiln_3381_patch.tif (bbox [22,20]→[28,26])
# Saved kiln_3382_patch.tif (bbox [20,24]→[26,30])
# Saved kiln_3383_patch.tif (bbox [20,24]→[26,30])
# Saved kiln_3384_patch.tif (bbox [3,46]→[9,52])
# Saved kiln_3385_patch.tif (bbox [3,46]→[9,52])
# Saved kiln_3386_patch.tif (bbox [0,60]→[4,63])
# Saved kiln_3387_patch.tif (bbox [0,60]→[4,63])
# Saved kiln_3388_patch.tif (bbox [14,31]→[20,37])
# Saved kiln_3389_patch.tif (bbox [14,31]→[20,37])
# Saved kiln_3390_patch.tif (bbox [25,37]→[31,43])
# Saved kiln_3391_patch.tif (bbox [25,37]→[31,43])
# Saved kiln_3392_patch.tif (bbox [7,24]→[13,30])
# Saved kiln_3393_patch.tif (bbox [7,24]→[13,30])
# Saved kiln_3394_patch.tif (bbox [38,43]→[44,49])
# Saved kiln_3395_patch.tif (bbox [38,43]→[44,49])
# Saved kiln_3396_patch.tif (bbox [46,53]→[52,59])
# Saved kiln_3397_patch.tif (bbox [46,53]→[52,59])
# Saved kiln_3398_patch.tif (bbox [28,25]→[34,31])
# Saved kiln_3399_patch.tif (bbox [28,25]→[34,31])
# Saved kiln_3400_patch.tif (bbox [0,56]→[4,62])
# Saved kiln_3401_patch.tif (bbox [0,56]→[4,62])
# Saved kiln_3402_patch.tif (bbox [0,45]→[5,51])
# Saved kiln_3403_patch.tif (bbox [0,45]→[5,51])
# Saved kiln_3404_patch.tif (bbox [34,13]→[40,19])
# Saved kiln_3405_patch.tif (bbox [34,13]→[40,19])
# Saved kiln_3406_patch.tif (bbox [47,57]→[53,63])
# Saved kiln_3407_patch.tif (bbox [47,57]→[53,63])
# Saved kiln_3408_patch.tif (bbox [9,14]→[15,20])
# Saved kiln_3409_patch.tif (bbox [9,14]→[15,20])
# Saved kiln_3410_patch.tif (bbox [11,22]→[17,28])
# Saved kiln_3411_patch.tif (bbox [11,22]→[17,28])
# Saved kiln_3412_patch.tif (bbox [37,37]→[43,43])
# Saved kiln_3413_patch.tif (bbox [37,37]→[43,43])
# Saved kiln_3414_patch.tif (bbox [19,19]→[25,25])
# Saved kiln_3415_patch.tif (bbox [19,19]→[25,25])
# Saved kiln_3416_patch.tif (bbox [39,14]→[45,20])
# Saved kiln_3417_patch.tif (bbox [39,14]→[45,20])
# Saved kiln_3418_patch.tif (bbox [39,2]→[45,8])
# Saved kiln_3419_patch.tif (bbox [39,2]→[45,8])
# Saved kiln_3420_patch.tif (bbox [0,15]→[4,21])
# Saved kiln_3421_patch.tif (bbox [0,15]→[4,21])
# Saved kiln_3422_patch.tif (bbox [46,31]→[52,37])
# Saved kiln_3423_patch.tif (bbox [46,31]→[52,37])
# Saved kiln_3424_patch.tif (bbox [10,2]→[16,8])
# Saved kiln_3425_patch.tif (bbox [10,2]→[16,8])
# Saved kiln_3426_patch.tif (bbox [2,53]→[8,59])
# Saved kiln_3427_patch.tif (bbox [2,53]→[8,59])
# Saved kiln_3428_patch.tif (bbox [28,14]→[34,20])
# Saved kiln_3429_patch.tif (bbox [28,14]→[34,20])
# Saved kiln_3430_patch.tif (bbox [55,56]→[61,62])
# Saved kiln_3431_patch.tif (bbox [55,56]→[61,62])
# Saved kiln_3432_patch.tif (bbox [58,2]→[63,8])
# Saved kiln_3433_patch.tif (bbox [58,2]→[63,8])
# Saved kiln_3434_patch.tif (bbox [37,41]→[43,47])
# Saved kiln_3435_patch.tif (bbox [37,41]→[43,47])
# Saved kiln_3436_patch.tif (bbox [46,44]→[52,50])
# Saved kiln_3437_patch.tif (bbox [46,44]→[52,50])
# Saved kiln_3438_patch.tif (bbox [57,25]→[63,31])
# Saved kiln_3439_patch.tif (bbox [57,25]→[63,31])
# Saved kiln_3440_patch.tif (bbox [4,9]→[10,15])
# Saved kiln_3441_patch.tif (bbox [4,9]→[10,15])
# Saved kiln_3442_patch.tif (bbox [50,31]→[56,37])
# Saved kiln_3443_patch.tif (bbox [50,31]→[56,37])
# Saved kiln_3444_patch.tif (bbox [37,21]→[43,27])
# Saved kiln_3445_patch.tif (bbox [37,21]→[43,27])
# Saved kiln_3446_patch.tif (bbox [5,0]→[11,3])
# Saved kiln_3447_patch.tif (bbox [5,0]→[11,3])
# Saved kiln_3448_patch.tif (bbox [10,29]→[16,35])
# Saved kiln_3449_patch.tif (bbox [10,29]→[16,35])
# Saved kiln_3450_patch.tif (bbox [7,6]→[13,12])
# Saved kiln_3451_patch.tif (bbox [7,6]→[13,12])
# Saved kiln_3452_patch.tif (bbox [60,57]→[63,63])
# Saved kiln_3453_patch.tif (bbox [60,57]→[63,63])
# Saved kiln_3454_patch.tif (bbox [24,3]→[30,9])
# Saved kiln_3455_patch.tif (bbox [24,3]→[30,9])
# Saved kiln_3456_patch.tif (bbox [47,58]→[53,63])
# Saved kiln_3457_patch.tif (bbox [47,58]→[53,63])
# Saved kiln_3458_patch.tif (bbox [0,33]→[5,39])
# Saved kiln_3459_patch.tif (bbox [0,33]→[5,39])
# Saved kiln_3460_patch.tif (bbox [38,31]→[44,37])
# Saved kiln_3461_patch.tif (bbox [38,31]→[44,37])
# Saved kiln_3462_patch.tif (bbox [7,25]→[13,31])
# Saved kiln_3463_patch.tif (bbox [7,25]→[13,31])
# Saved kiln_3464_patch.tif (bbox [19,23]→[25,29])
# Saved kiln_3465_patch.tif (bbox [19,23]→[25,29])
# Saved kiln_3466_patch.tif (bbox [40,23]→[46,29])
# Saved kiln_3467_patch.tif (bbox [40,23]→[46,29])
# Saved kiln_3468_patch.tif (bbox [16,42]→[22,48])
# Saved kiln_3469_patch.tif (bbox [16,42]→[22,48])
# Saved kiln_3470_patch.tif (bbox [5,48]→[11,54])
# Saved kiln_3471_patch.tif (bbox [5,48]→[11,54])
# Saved kiln_3472_patch.tif (bbox [4,16]→[10,22])
# Saved kiln_3473_patch.tif (bbox [4,16]→[10,22])
# Saved kiln_3474_patch.tif (bbox [11,6]→[17,12])
# Saved kiln_3475_patch.tif (bbox [11,6]→[17,12])
# Saved kiln_3476_patch.tif (bbox [0,50]→[3,56])
# Saved kiln_3477_patch.tif (bbox [0,50]→[3,56])
# Saved kiln_3478_patch.tif (bbox [59,60]→[63,63])
# Saved kiln_3479_patch.tif (bbox [59,60]→[63,63])
# Saved kiln_3480_patch.tif (bbox [58,25]→[63,31])
# Saved kiln_3481_patch.tif (bbox [58,25]→[63,31])
# Saved kiln_3482_patch.tif (bbox [7,17]→[13,23])
# Saved kiln_3483_patch.tif (bbox [7,17]→[13,23])
# Saved kiln_3484_patch.tif (bbox [57,49]→[63,55])
# Saved kiln_3485_patch.tif (bbox [57,49]→[63,55])
# Saved kiln_3486_patch.tif (bbox [39,21]→[45,27])
# Saved kiln_3487_patch.tif (bbox [39,21]→[45,27])
# Saved kiln_3488_patch.tif (bbox [43,0]→[49,6])
# Saved kiln_3489_patch.tif (bbox [43,0]→[49,6])
# Saved kiln_3490_patch.tif (bbox [3,57]→[9,63])
# Saved kiln_3491_patch.tif (bbox [3,57]→[9,63])
# Saved kiln_3492_patch.tif (bbox [30,35]→[36,41])
# Saved kiln_3493_patch.tif (bbox [30,35]→[36,41])
# Saved kiln_3494_patch.tif (bbox [19,1]→[25,7])
# Saved kiln_3495_patch.tif (bbox [19,1]→[25,7])
# Saved kiln_3496_patch.tif (bbox [22,46]→[28,52])
# Saved kiln_3497_patch.tif (bbox [22,46]→[28,52])
# Saved kiln_3498_patch.tif (bbox [26,29]→[32,35])
# Saved kiln_3499_patch.tif (bbox [26,29]→[32,35])
# Saved kiln_3500_patch.tif (bbox [26,0]→[32,4])
# Saved kiln_3501_patch.tif (bbox [26,0]→[32,4])
# Saved kiln_3502_patch.tif (bbox [48,0]→[54,3])
# Saved kiln_3503_patch.tif (bbox [48,0]→[54,3])
# Saved kiln_3504_patch.tif (bbox [42,59]→[48,63])
# Saved kiln_3505_patch.tif (bbox [42,59]→[48,63])
# Saved kiln_3506_patch.tif (bbox [54,0]→[60,6])
# Saved kiln_3507_patch.tif (bbox [54,0]→[60,6])
# Saved kiln_3508_patch.tif (bbox [20,21]→[26,27])
# Saved kiln_3509_patch.tif (bbox [20,21]→[26,27])
# Saved kiln_3510_patch.tif (bbox [41,16]→[47,22])
# Saved kiln_3511_patch.tif (bbox [41,16]→[47,22])
# Saved kiln_3512_patch.tif (bbox [41,3]→[47,9])
# Saved kiln_3513_patch.tif (bbox [41,3]→[47,9])
# Saved kiln_3514_patch.tif (bbox [47,40]→[53,46])
# Saved kiln_3515_patch.tif (bbox [47,40]→[53,46])
# Saved kiln_3516_patch.tif (bbox [58,11]→[63,17])
# Saved kiln_3517_patch.tif (bbox [58,11]→[63,17])
# Saved kiln_3518_patch.tif (bbox [57,29]→[63,35])
# Saved kiln_3519_patch.tif (bbox [57,29]→[63,35])
# Saved kiln_3520_patch.tif (bbox [55,27]→[61,33])
# Saved kiln_3521_patch.tif (bbox [55,27]→[61,33])
# Saved kiln_3522_patch.tif (bbox [33,46]→[39,52])
# Saved kiln_3523_patch.tif (bbox [33,46]→[39,52])
# Saved kiln_3524_patch.tif (bbox [16,17]→[22,23])
# Saved kiln_3525_patch.tif (bbox [16,17]→[22,23])
# Saved kiln_3526_patch.tif (bbox [49,15]→[55,21])
# Saved kiln_3527_patch.tif (bbox [49,15]→[55,21])
# Saved kiln_3528_patch.tif (bbox [34,0]→[40,6])
# Saved kiln_3529_patch.tif (bbox [34,0]→[40,6])
# Saved kiln_3530_patch.tif (bbox [6,49]→[12,55])
# Saved kiln_3531_patch.tif (bbox [6,49]→[12,55])
# Saved kiln_3532_patch.tif (bbox [38,18]→[44,24])
# Saved kiln_3533_patch.tif (bbox [38,18]→[44,24])
# Saved kiln_3534_patch.tif (bbox [15,53]→[21,59])
# Saved kiln_3535_patch.tif (bbox [15,53]→[21,59])
# Saved kiln_3536_patch.tif (bbox [3,49]→[9,55])
# Saved kiln_3537_patch.tif (bbox [3,49]→[9,55])
# Saved kiln_3538_patch.tif (bbox [22,31]→[28,37])
# Saved kiln_3539_patch.tif (bbox [22,31]→[28,37])
# Saved kiln_3540_patch.tif (bbox [0,36]→[3,42])
# Saved kiln_3541_patch.tif (bbox [0,36]→[3,42])
# Saved kiln_3542_patch.tif (bbox [46,41]→[52,47])
# Saved kiln_3543_patch.tif (bbox [46,41]→[52,47])
# Saved kiln_3544_patch.tif (bbox [22,22]→[28,28])
# Saved kiln_3545_patch.tif (bbox [22,22]→[28,28])
# Saved kiln_3546_patch.tif (bbox [18,8]→[24,14])
# Saved kiln_3547_patch.tif (bbox [18,8]→[24,14])
# Saved kiln_3548_patch.tif (bbox [16,0]→[22,5])
# Saved kiln_3549_patch.tif (bbox [16,0]→[22,5])
# Saved kiln_3550_patch.tif (bbox [52,55]→[58,61])
# Saved kiln_3551_patch.tif (bbox [52,55]→[58,61])
# Saved kiln_3552_patch.tif (bbox [25,51]→[31,57])
# Saved kiln_3553_patch.tif (bbox [25,51]→[31,57])
# Saved kiln_3554_patch.tif (bbox [4,47]→[10,53])
# Saved kiln_3555_patch.tif (bbox [4,47]→[10,53])
# Saved kiln_3556_patch.tif (bbox [53,44]→[59,50])
# Saved kiln_3557_patch.tif (bbox [53,44]→[59,50])
# Saved kiln_3558_patch.tif (bbox [27,5]→[33,11])
# Saved kiln_3559_patch.tif (bbox [27,5]→[33,11])
# Saved kiln_3560_patch.tif (bbox [25,51]→[31,57])
# Saved kiln_3561_patch.tif (bbox [25,51]→[31,57])
# Saved kiln_3562_patch.tif (bbox [2,20]→[8,26])
# Saved kiln_3563_patch.tif (bbox [2,20]→[8,26])
# Saved kiln_3564_patch.tif (bbox [14,8]→[20,14])
# Saved kiln_3565_patch.tif (bbox [14,8]→[20,14])
# Saved kiln_3566_patch.tif (bbox [24,0]→[30,4])
# Saved kiln_3567_patch.tif (bbox [24,0]→[30,4])
# Saved kiln_3568_patch.tif (bbox [19,22]→[25,28])
# Saved kiln_3569_patch.tif (bbox [19,22]→[25,28])
# Saved kiln_3570_patch.tif (bbox [0,0]→[4,3])
# Saved kiln_3571_patch.tif (bbox [0,0]→[4,3])
# Saved kiln_3572_patch.tif (bbox [18,46]→[24,52])
# Saved kiln_3573_patch.tif (bbox [18,46]→[24,52])
# Saved kiln_3574_patch.tif (bbox [39,15]→[45,21])
# Saved kiln_3575_patch.tif (bbox [39,15]→[45,21])
# Saved kiln_3576_patch.tif (bbox [59,5]→[63,11])
# Saved kiln_3577_patch.tif (bbox [59,5]→[63,11])
# Saved kiln_3578_patch.tif (bbox [39,56]→[45,62])
# Saved kiln_3579_patch.tif (bbox [39,56]→[45,62])
# Saved kiln_3580_patch.tif (bbox [43,39]→[49,45])
# Saved kiln_3581_patch.tif (bbox [43,39]→[49,45])
# Saved kiln_3582_patch.tif (bbox [0,54]→[3,60])
# Saved kiln_3583_patch.tif (bbox [0,54]→[3,60])
# Saved kiln_3584_patch.tif (bbox [23,40]→[29,46])
# Saved kiln_3585_patch.tif (bbox [23,40]→[29,46])
# Saved kiln_3586_patch.tif (bbox [43,33]→[49,39])
# Saved kiln_3587_patch.tif (bbox [43,33]→[49,39])
# Saved kiln_3588_patch.tif (bbox [11,32]→[17,38])
# Saved kiln_3589_patch.tif (bbox [11,32]→[17,38])
# Saved kiln_3590_patch.tif (bbox [55,21]→[61,27])
# Saved kiln_3591_patch.tif (bbox [55,21]→[61,27])
# Saved kiln_3592_patch.tif (bbox [26,16]→[32,22])
# Saved kiln_3593_patch.tif (bbox [26,16]→[32,22])
# Saved kiln_3594_patch.tif (bbox [45,0]→[51,6])
# Saved kiln_3595_patch.tif (bbox [45,0]→[51,6])
# Saved kiln_3596_patch.tif (bbox [40,12]→[46,18])
# Saved kiln_3597_patch.tif (bbox [40,12]→[46,18])
# Saved kiln_3598_patch.tif (bbox [18,57]→[24,63])
# Saved kiln_3599_patch.tif (bbox [18,57]→[24,63])
# Saved kiln_3600_patch.tif (bbox [42,12]→[48,18])
# Saved kiln_3601_patch.tif (bbox [42,12]→[48,18])
# Saved kiln_3602_patch.tif (bbox [60,5]→[63,11])
# Saved kiln_3603_patch.tif (bbox [60,5]→[63,11])
# Saved kiln_3604_patch.tif (bbox [60,5]→[63,11])
# Saved kiln_3605_patch.tif (bbox [60,5]→[63,11])
# Saved kiln_3606_patch.tif (bbox [57,37]→[63,43])
# Saved kiln_3607_patch.tif (bbox [57,37]→[63,43])
# Saved kiln_3608_patch.tif (bbox [1,49]→[7,55])
# Saved kiln_3609_patch.tif (bbox [1,49]→[7,55])
# Saved kiln_3610_patch.tif (bbox [35,31]→[41,37])
# Saved kiln_3611_patch.tif (bbox [35,31]→[41,37])
# Saved kiln_3612_patch.tif (bbox [30,28]→[36,34])
# Saved kiln_3613_patch.tif (bbox [30,28]→[36,34])
# Saved kiln_3614_patch.tif (bbox [52,60]→[58,63])
# Saved kiln_3615_patch.tif (bbox [52,60]→[58,63])
# Saved kiln_3616_patch.tif (bbox [21,39]→[27,45])
# Saved kiln_3617_patch.tif (bbox [21,39]→[27,45])
# Saved kiln_3618_patch.tif (bbox [16,44]→[22,50])
# Saved kiln_3619_patch.tif (bbox [16,44]→[22,50])
# Saved kiln_3620_patch.tif (bbox [27,37]→[33,43])
# Saved kiln_3621_patch.tif (bbox [27,37]→[33,43])
# Saved kiln_3622_patch.tif (bbox [47,26]→[53,32])
# Saved kiln_3623_patch.tif (bbox [47,26]→[53,32])
# Saved kiln_3624_patch.tif (bbox [27,26]→[33,32])
# Saved kiln_3625_patch.tif (bbox [27,26]→[33,32])
# Saved kiln_3626_patch.tif (bbox [31,24]→[37,30])
# Saved kiln_3627_patch.tif (bbox [31,24]→[37,30])
# Saved kiln_3628_patch.tif (bbox [41,17]→[47,23])
# Saved kiln_3629_patch.tif (bbox [41,17]→[47,23])
# Saved kiln_3630_patch.tif (bbox [42,15]→[48,21])
# Saved kiln_3631_patch.tif (bbox [42,15]→[48,21])
# Saved kiln_3632_patch.tif (bbox [12,16]→[18,22])
# Saved kiln_3633_patch.tif (bbox [12,16]→[18,22])
# Saved kiln_3634_patch.tif (bbox [0,9]→[3,15])
# Saved kiln_3635_patch.tif (bbox [0,9]→[3,15])
# Saved kiln_3636_patch.tif (bbox [7,1]→[13,7])
# Saved kiln_3637_patch.tif (bbox [7,1]→[13,7])
# Saved kiln_3638_patch.tif (bbox [38,0]→[44,4])
# Saved kiln_3639_patch.tif (bbox [38,0]→[44,4])
# Saved kiln_3640_patch.tif (bbox [35,56]→[41,62])
# Saved kiln_3641_patch.tif (bbox [35,56]→[41,62])
# Saved kiln_3642_patch.tif (bbox [43,50]→[49,56])
# Saved kiln_3643_patch.tif (bbox [43,50]→[49,56])
# Saved kiln_3644_patch.tif (bbox [9,47]→[15,53])
# Saved kiln_3645_patch.tif (bbox [9,47]→[15,53])
# Saved kiln_3646_patch.tif (bbox [39,43]→[45,49])
# Saved kiln_3647_patch.tif (bbox [39,43]→[45,49])
# Saved kiln_3648_patch.tif (bbox [0,58]→[5,63])
# Saved kiln_3649_patch.tif (bbox [0,58]→[5,63])
# Saved kiln_3650_patch.tif (bbox [28,0]→[34,6])
# Saved kiln_3651_patch.tif (bbox [28,0]→[34,6])
# Saved kiln_3652_patch.tif (bbox [14,47]→[20,53])
# Saved kiln_3653_patch.tif (bbox [14,47]→[20,53])
# Saved kiln_3654_patch.tif (bbox [34,40]→[40,46])
# Saved kiln_3655_patch.tif (bbox [34,40]→[40,46])
# Saved kiln_3656_patch.tif (bbox [44,37]→[50,43])
# Saved kiln_3657_patch.tif (bbox [44,37]→[50,43])
# Saved kiln_3658_patch.tif (bbox [11,36]→[17,42])
# Saved kiln_3659_patch.tif (bbox [11,36]→[17,42])
# Saved kiln_3660_patch.tif (bbox [43,12]→[49,18])
# Saved kiln_3661_patch.tif (bbox [43,12]→[49,18])
# Saved kiln_3662_patch.tif (bbox [32,25]→[38,31])
# Saved kiln_3663_patch.tif (bbox [32,25]→[38,31])
# Saved kiln_3664_patch.tif (bbox [35,24]→[41,30])
# Saved kiln_3665_patch.tif (bbox [35,24]→[41,30])
# Saved kiln_3666_patch.tif (bbox [12,20]→[18,26])
# Saved kiln_3667_patch.tif (bbox [12,20]→[18,26])
# Saved kiln_3668_patch.tif (bbox [49,52]→[55,58])
# Saved kiln_3669_patch.tif (bbox [49,52]→[55,58])
# Saved kiln_3670_patch.tif (bbox [0,33]→[4,39])
# Saved kiln_3671_patch.tif (bbox [0,33]→[4,39])
# Saved kiln_3672_patch.tif (bbox [36,24]→[42,30])
# Saved kiln_3673_patch.tif (bbox [36,24]→[42,30])
# Saved kiln_3674_patch.tif (bbox [14,23]→[20,29])
# Saved kiln_3675_patch.tif (bbox [14,23]→[20,29])
# Saved kiln_3676_patch.tif (bbox [0,22]→[6,28])
# Saved kiln_3677_patch.tif (bbox [0,22]→[6,28])
# Saved kiln_3678_patch.tif (bbox [58,22]→[63,28])
# Saved kiln_3679_patch.tif (bbox [58,22]→[63,28])
# Saved kiln_3680_patch.tif (bbox [11,5]→[17,11])
# Saved kiln_3681_patch.tif (bbox [11,5]→[17,11])
# Saved kiln_3682_patch.tif (bbox [31,35]→[37,41])
# Saved kiln_3683_patch.tif (bbox [31,35]→[37,41])
# Saved kiln_3684_patch.tif (bbox [45,28]→[51,34])
# Saved kiln_3685_patch.tif (bbox [45,28]→[51,34])
# Saved kiln_3686_patch.tif (bbox [22,14]→[28,20])
# Saved kiln_3687_patch.tif (bbox [22,14]→[28,20])
# Saved kiln_3688_patch.tif (bbox [16,12]→[22,18])
# Saved kiln_3689_patch.tif (bbox [16,12]→[22,18])
# Saved kiln_3690_patch.tif (bbox [38,5]→[44,11])
# Saved kiln_3691_patch.tif (bbox [38,5]→[44,11])
# Saved kiln_3692_patch.tif (bbox [47,0]→[53,4])
# Saved kiln_3693_patch.tif (bbox [47,0]→[53,4])
# Saved kiln_3694_patch.tif (bbox [3,60]→[9,63])
# Saved kiln_3695_patch.tif (bbox [3,60]→[9,63])
# Saved kiln_3696_patch.tif (bbox [46,39]→[52,45])
# Saved kiln_3697_patch.tif (bbox [46,39]→[52,45])
# Saved kiln_3698_patch.tif (bbox [0,0]→[4,5])
# Saved kiln_3699_patch.tif (bbox [0,0]→[4,5])
# Saved kiln_3700_patch.tif (bbox [47,48]→[53,54])
# Saved kiln_3701_patch.tif (bbox [47,48]→[53,54])
# Saved kiln_3702_patch.tif (bbox [12,36]→[18,42])
# Saved kiln_3703_patch.tif (bbox [12,36]→[18,42])
# Saved kiln_3704_patch.tif (bbox [9,60]→[15,63])
# Saved kiln_3705_patch.tif (bbox [9,60]→[15,63])
# Saved kiln_3706_patch.tif (bbox [46,22]→[52,28])
# Saved kiln_3707_patch.tif (bbox [46,22]→[52,28])
# Saved kiln_3708_patch.tif (bbox [36,59]→[42,63])
# Saved kiln_3709_patch.tif (bbox [36,59]→[42,63])
# Saved kiln_3710_patch.tif (bbox [14,11]→[20,17])
# Saved kiln_3711_patch.tif (bbox [14,11]→[20,17])
# Saved kiln_3712_patch.tif (bbox [5,3]→[11,9])
# Saved kiln_3713_patch.tif (bbox [5,3]→[11,9])
# Saved kiln_3714_patch.tif (bbox [1,35]→[7,41])
# Saved kiln_3715_patch.tif (bbox [1,35]→[7,41])
# Saved kiln_3716_patch.tif (bbox [14,55]→[20,61])
# Saved kiln_3717_patch.tif (bbox [14,55]→[20,61])
# Saved kiln_3718_patch.tif (bbox [34,18]→[40,24])
# Saved kiln_3719_patch.tif (bbox [34,18]→[40,24])
# Saved kiln_3720_patch.tif (bbox [3,54]→[9,60])
# Saved kiln_3721_patch.tif (bbox [3,54]→[9,60])
# Saved kiln_3722_patch.tif (bbox [30,48]→[36,54])
# Saved kiln_3723_patch.tif (bbox [30,48]→[36,54])
# Saved kiln_3724_patch.tif (bbox [4,15]→[10,21])
# Saved kiln_3725_patch.tif (bbox [4,15]→[10,21])
# Saved kiln_3726_patch.tif (bbox [0,46]→[6,52])
# Saved kiln_3727_patch.tif (bbox [0,46]→[6,52])
# Saved kiln_3728_patch.tif (bbox [40,11]→[46,17])
# Saved kiln_3729_patch.tif (bbox [40,11]→[46,17])
# Saved kiln_3730_patch.tif (bbox [26,4]→[32,10])
# Saved kiln_3731_patch.tif (bbox [26,4]→[32,10])
# Saved kiln_3732_patch.tif (bbox [9,50]→[15,56])
# Saved kiln_3733_patch.tif (bbox [9,50]→[15,56])
# Saved kiln_3734_patch.tif (bbox [14,35]→[20,41])
# Saved kiln_3735_patch.tif (bbox [14,35]→[20,41])
# Saved kiln_3736_patch.tif (bbox [24,33]→[30,39])
# Saved kiln_3737_patch.tif (bbox [24,33]→[30,39])
# Saved kiln_3738_patch.tif (bbox [36,14]→[42,20])
# Saved kiln_3739_patch.tif (bbox [36,14]→[42,20])
# Saved kiln_3740_patch.tif (bbox [48,0]→[54,6])
# Saved kiln_3741_patch.tif (bbox [48,0]→[54,6])
# Saved kiln_3742_patch.tif (bbox [39,57]→[45,63])
# Saved kiln_3743_patch.tif (bbox [39,57]→[45,63])
# Saved kiln_3744_patch.tif (bbox [58,34]→[63,40])
# Saved kiln_3745_patch.tif (bbox [58,34]→[63,40])
# Saved kiln_3746_patch.tif (bbox [5,4]→[11,10])
# Saved kiln_3747_patch.tif (bbox [5,4]→[11,10])
# Saved kiln_3748_patch.tif (bbox [4,34]→[10,40])
# Saved kiln_3749_patch.tif (bbox [4,34]→[10,40])
# Saved kiln_3750_patch.tif (bbox [55,41]→[61,47])
# Saved kiln_3751_patch.tif (bbox [55,41]→[61,47])
# Saved kiln_3752_patch.tif (bbox [28,52]→[34,58])
# Saved kiln_3753_patch.tif (bbox [28,52]→[34,58])
# Saved kiln_3754_patch.tif (bbox [8,47]→[14,53])
# Saved kiln_3755_patch.tif (bbox [8,47]→[14,53])
# Saved kiln_3756_patch.tif (bbox [42,29]→[48,35])
# Saved kiln_3757_patch.tif (bbox [42,29]→[48,35])
# Saved kiln_3758_patch.tif (bbox [33,55]→[39,61])
# Saved kiln_3759_patch.tif (bbox [33,55]→[39,61])
# Saved kiln_3760_patch.tif (bbox [33,4]→[39,10])
# Saved kiln_3761_patch.tif (bbox [33,4]→[39,10])
# Saved kiln_3762_patch.tif (bbox [23,15]→[29,21])
# Saved kiln_3763_patch.tif (bbox [23,15]→[29,21])
# Saved kiln_3764_patch.tif (bbox [60,39]→[63,45])
# Saved kiln_3765_patch.tif (bbox [60,39]→[63,45])
# Saved kiln_3766_patch.tif (bbox [39,60]→[45,63])
# Saved kiln_3767_patch.tif (bbox [39,60]→[45,63])
# Saved kiln_3768_patch.tif (bbox [3,56]→[9,62])
# Saved kiln_3769_patch.tif (bbox [3,56]→[9,62])
# Saved kiln_3770_patch.tif (bbox [37,24]→[43,30])
# Saved kiln_3771_patch.tif (bbox [37,24]→[43,30])
# Saved kiln_3772_patch.tif (bbox [10,23]→[16,29])
# Saved kiln_3773_patch.tif (bbox [10,23]→[16,29])
# Saved kiln_3774_patch.tif (bbox [35,31]→[41,37])
# Saved kiln_3775_patch.tif (bbox [35,31]→[41,37])
# Saved kiln_3776_patch.tif (bbox [26,0]→[32,6])
# Saved kiln_3777_patch.tif (bbox [26,0]→[32,6])
# Saved kiln_3778_patch.tif (bbox [0,32]→[3,38])
# Saved kiln_3779_patch.tif (bbox [0,32]→[3,38])
# Saved kiln_3780_patch.tif (bbox [14,35]→[20,41])
# Saved kiln_3781_patch.tif (bbox [14,35]→[20,41])
# Saved kiln_3782_patch.tif (bbox [21,30]→[27,36])
# Saved kiln_3783_patch.tif (bbox [21,30]→[27,36])
# Saved kiln_3784_patch.tif (bbox [9,28]→[15,34])
# Saved kiln_3785_patch.tif (bbox [9,28]→[15,34])
# Saved kiln_3786_patch.tif (bbox [42,11]→[48,17])
# Saved kiln_3787_patch.tif (bbox [42,11]→[48,17])
# Saved kiln_3788_patch.tif (bbox [58,7]→[63,13])
# Saved kiln_3789_patch.tif (bbox [58,7]→[63,13])
# Saved kiln_3790_patch.tif (bbox [34,36]→[40,42])
# Saved kiln_3791_patch.tif (bbox [34,36]→[40,42])
# Saved kiln_3792_patch.tif (bbox [22,35]→[28,41])
# Saved kiln_3793_patch.tif (bbox [22,35]→[28,41])
# Saved kiln_3794_patch.tif (bbox [8,15]→[14,21])
# Saved kiln_3795_patch.tif (bbox [8,15]→[14,21])
# Saved kiln_3796_patch.tif (bbox [14,9]→[20,15])
# Saved kiln_3797_patch.tif (bbox [14,9]→[20,15])
# Saved kiln_3798_patch.tif (bbox [21,14]→[27,20])
# Saved kiln_3799_patch.tif (bbox [21,14]→[27,20])
# Saved kiln_3800_patch.tif (bbox [18,58]→[24,63])
# Saved kiln_3801_patch.tif (bbox [18,58]→[24,63])
# Saved kiln_3802_patch.tif (bbox [46,60]→[52,63])
# Saved kiln_3803_patch.tif (bbox [46,60]→[52,63])
# Saved kiln_3804_patch.tif (bbox [13,30]→[19,36])
# Saved kiln_3805_patch.tif (bbox [13,30]→[19,36])
# Saved kiln_3806_patch.tif (bbox [44,33]→[50,39])
# Saved kiln_3807_patch.tif (bbox [44,33]→[50,39])
# Saved kiln_3808_patch.tif (bbox [7,31]→[13,37])
# Saved kiln_3809_patch.tif (bbox [7,31]→[13,37])
# Saved kiln_3810_patch.tif (bbox [30,26]→[36,32])
# Saved kiln_3811_patch.tif (bbox [30,26]→[36,32])
# Saved kiln_3812_patch.tif (bbox [41,28]→[47,34])
# Saved kiln_3813_patch.tif (bbox [41,28]→[47,34])
# Saved kiln_3814_patch.tif (bbox [5,15]→[11,21])
# Saved kiln_3815_patch.tif (bbox [5,15]→[11,21])
# Saved kiln_3816_patch.tif (bbox [21,0]→[27,6])
# Saved kiln_3817_patch.tif (bbox [21,0]→[27,6])
# Saved kiln_3818_patch.tif (bbox [25,58]→[31,63])
# Saved kiln_3819_patch.tif (bbox [25,58]→[31,63])
# Saved kiln_3820_patch.tif (bbox [17,10]→[23,16])
# Saved kiln_3821_patch.tif (bbox [17,10]→[23,16])
# Saved kiln_3822_patch.tif (bbox [30,0]→[36,3])
# Saved kiln_3823_patch.tif (bbox [30,0]→[36,3])
# Saved kiln_3824_patch.tif (bbox [15,0]→[21,4])
# Saved kiln_3825_patch.tif (bbox [15,0]→[21,4])
# Saved kiln_3826_patch.tif (bbox [38,54]→[44,60])
# Saved kiln_3827_patch.tif (bbox [38,54]→[44,60])
# Saved kiln_3828_patch.tif (bbox [37,37]→[43,43])
# Saved kiln_3829_patch.tif (bbox [37,37]→[43,43])
# Saved kiln_3830_patch.tif (bbox [29,28]→[35,34])
# Saved kiln_3831_patch.tif (bbox [29,28]→[35,34])
# Saved kiln_3832_patch.tif (bbox [48,3]→[54,9])
# Saved kiln_3833_patch.tif (bbox [48,3]→[54,9])
# Saved kiln_3834_patch.tif (bbox [0,15]→[6,21])
# Saved kiln_3835_patch.tif (bbox [0,15]→[6,21])
# Saved kiln_3836_patch.tif (bbox [51,32]→[57,38])
# Saved kiln_3837_patch.tif (bbox [51,32]→[57,38])
# Saved kiln_3838_patch.tif (bbox [36,50]→[42,56])
# Saved kiln_3839_patch.tif (bbox [36,50]→[42,56])
# Saved kiln_3840_patch.tif (bbox [31,14]→[37,20])
# Saved kiln_3841_patch.tif (bbox [31,14]→[37,20])
# Saved kiln_3842_patch.tif (bbox [8,31]→[14,37])
# Saved kiln_3843_patch.tif (bbox [8,31]→[14,37])
# Saved kiln_3844_patch.tif (bbox [21,60]→[27,63])
# Saved kiln_3845_patch.tif (bbox [21,60]→[27,63])
# Saved kiln_3846_patch.tif (bbox [57,57]→[63,63])
# Saved kiln_3847_patch.tif (bbox [57,57]→[63,63])
# Saved kiln_3848_patch.tif (bbox [34,51]→[40,57])
# Saved kiln_3849_patch.tif (bbox [34,51]→[40,57])
# Saved kiln_3850_patch.tif (bbox [12,37]→[18,43])
# Saved kiln_3851_patch.tif (bbox [12,37]→[18,43])
# Saved kiln_3852_patch.tif (bbox [23,40]→[29,46])
# Saved kiln_3853_patch.tif (bbox [23,40]→[29,46])
# Saved kiln_3854_patch.tif (bbox [11,54]→[17,60])
# Saved kiln_3855_patch.tif (bbox [11,54]→[17,60])
# Saved kiln_3856_patch.tif (bbox [30,15]→[36,21])
# Saved kiln_3857_patch.tif (bbox [30,15]→[36,21])
# Saved kiln_3858_patch.tif (bbox [40,50]→[46,56])
# Saved kiln_3859_patch.tif (bbox [40,50]→[46,56])
# Saved kiln_3860_patch.tif (bbox [3,41]→[9,47])
# Saved kiln_3861_patch.tif (bbox [3,41]→[9,47])
# Saved kiln_3862_patch.tif (bbox [47,52]→[53,58])
# Saved kiln_3863_patch.tif (bbox [47,52]→[53,58])
# Saved kiln_3864_patch.tif (bbox [10,53]→[16,59])
# Saved kiln_3865_patch.tif (bbox [10,53]→[16,59])
# Saved kiln_3866_patch.tif (bbox [48,35]→[54,41])
# Saved kiln_3867_patch.tif (bbox [48,35]→[54,41])
# Saved kiln_3868_patch.tif (bbox [19,7]→[25,13])
# Saved kiln_3869_patch.tif (bbox [19,7]→[25,13])
# Saved kiln_3870_patch.tif (bbox [10,31]→[16,37])
# Saved kiln_3871_patch.tif (bbox [10,31]→[16,37])
# Saved kiln_3872_patch.tif (bbox [15,53]→[21,59])
# Saved kiln_3873_patch.tif (bbox [15,53]→[21,59])
# Saved kiln_3874_patch.tif (bbox [53,47]→[59,53])
# Saved kiln_3875_patch.tif (bbox [53,47]→[59,53])
# Saved kiln_3876_patch.tif (bbox [24,0]→[30,6])
# Saved kiln_3877_patch.tif (bbox [24,0]→[30,6])
# Saved kiln_3878_patch.tif (bbox [52,58]→[58,63])
# Saved kiln_3879_patch.tif (bbox [52,58]→[58,63])
# Saved kiln_3880_patch.tif (bbox [36,24]→[42,30])
# Saved kiln_3881_patch.tif (bbox [36,24]→[42,30])
# Saved kiln_3882_patch.tif (bbox [27,13]→[33,19])
# Saved kiln_3883_patch.tif (bbox [27,13]→[33,19])
# Saved kiln_3884_patch.tif (bbox [58,15]→[63,21])
# Saved kiln_3885_patch.tif (bbox [58,15]→[63,21])
# Saved kiln_3886_patch.tif (bbox [0,8]→[3,14])
# Saved kiln_3887_patch.tif (bbox [0,8]→[3,14])
# Saved kiln_3888_patch.tif (bbox [55,51]→[61,57])
# Saved kiln_3889_patch.tif (bbox [55,51]→[61,57])
# Saved kiln_3890_patch.tif (bbox [53,0]→[59,4])
# Saved kiln_3891_patch.tif (bbox [53,0]→[59,4])
# Saved kiln_3892_patch.tif (bbox [48,42]→[54,48])
# Saved kiln_3893_patch.tif (bbox [48,42]→[54,48])
# Saved kiln_3894_patch.tif (bbox [45,41]→[51,47])
# Saved kiln_3895_patch.tif (bbox [45,41]→[51,47])
# Saved kiln_3896_patch.tif (bbox [51,4]→[57,10])
# Saved kiln_3897_patch.tif (bbox [51,4]→[57,10])
# Saved kiln_3898_patch.tif (bbox [6,3]→[12,9])
# Saved kiln_3899_patch.tif (bbox [6,3]→[12,9])
# Saved kiln_3900_patch.tif (bbox [56,54]→[62,60])
# Saved kiln_3901_patch.tif (bbox [56,54]→[62,60])
# Saved kiln_3902_patch.tif (bbox [30,3]→[36,9])
# Saved kiln_3903_patch.tif (bbox [30,3]→[36,9])
# Saved kiln_3904_patch.tif (bbox [33,60]→[39,63])
# Saved kiln_3905_patch.tif (bbox [33,60]→[39,63])
# Saved kiln_3906_patch.tif (bbox [21,52]→[27,58])
# Saved kiln_3907_patch.tif (bbox [21,52]→[27,58])
# Saved kiln_3908_patch.tif (bbox [53,4]→[59,10])
# Saved kiln_3909_patch.tif (bbox [53,4]→[59,10])
# Saved kiln_3910_patch.tif (bbox [32,0]→[38,6])
# Saved kiln_3911_patch.tif (bbox [32,0]→[38,6])
# Saved kiln_3912_patch.tif (bbox [19,9]→[25,15])
# Saved kiln_3913_patch.tif (bbox [19,9]→[25,15])
# Saved kiln_3914_patch.tif (bbox [42,37]→[48,43])
# Saved kiln_3915_patch.tif (bbox [42,37]→[48,43])
# Saved kiln_3916_patch.tif (bbox [38,18]→[44,24])
# Saved kiln_3917_patch.tif (bbox [38,18]→[44,24])
# Saved kiln_3918_patch.tif (bbox [60,16]→[63,22])
# Saved kiln_3919_patch.tif (bbox [60,16]→[63,22])
# Saved kiln_3920_patch.tif (bbox [1,37]→[7,43])
# Saved kiln_3921_patch.tif (bbox [1,37]→[7,43])
# Saved kiln_3922_patch.tif (bbox [25,26]→[31,32])
# Saved kiln_3923_patch.tif (bbox [25,26]→[31,32])
# Saved kiln_3924_patch.tif (bbox [46,0]→[52,5])
# Saved kiln_3925_patch.tif (bbox [46,0]→[52,5])
# Saved kiln_3926_patch.tif (bbox [11,55]→[17,61])
# Saved kiln_3927_patch.tif (bbox [11,55]→[17,61])
# Saved kiln_3928_patch.tif (bbox [60,22]→[63,28])
# Saved kiln_3929_patch.tif (bbox [60,22]→[63,28])
# Saved kiln_3930_patch.tif (bbox [0,46]→[6,52])
# Saved kiln_3931_patch.tif (bbox [0,46]→[6,52])
# Saved kiln_3932_patch.tif (bbox [13,36]→[19,42])
# Saved kiln_3933_patch.tif (bbox [13,36]→[19,42])
# Saved kiln_3934_patch.tif (bbox [32,48]→[38,54])
# Saved kiln_3935_patch.tif (bbox [32,48]→[38,54])
# Saved kiln_3936_patch.tif (bbox [15,8]→[21,14])
# Saved kiln_3937_patch.tif (bbox [15,8]→[21,14])
# Saved kiln_3938_patch.tif (bbox [54,43]→[60,49])
# Saved kiln_3939_patch.tif (bbox [54,43]→[60,49])
# Saved kiln_3940_patch.tif (bbox [22,27]→[28,33])
# Saved kiln_3941_patch.tif (bbox [22,27]→[28,33])
# Saved kiln_3942_patch.tif (bbox [41,51]→[47,57])
# Saved kiln_3943_patch.tif (bbox [41,51]→[47,57])
# Saved kiln_3944_patch.tif (bbox [3,49]→[9,55])
# Saved kiln_3945_patch.tif (bbox [3,49]→[9,55])
# Saved kiln_3946_patch.tif (bbox [60,50]→[63,56])
# Saved kiln_3947_patch.tif (bbox [60,50]→[63,56])
# Saved kiln_3948_patch.tif (bbox [4,0]→[10,4])
# Saved kiln_3949_patch.tif (bbox [4,0]→[10,4])
# Saved kiln_3950_patch.tif (bbox [23,23]→[29,29])
# Saved kiln_3951_patch.tif (bbox [23,23]→[29,29])
# Saved kiln_3952_patch.tif (bbox [25,16]→[31,22])
# Saved kiln_3953_patch.tif (bbox [25,16]→[31,22])
# Saved kiln_3954_patch.tif (bbox [26,40]→[32,46])
# Saved kiln_3955_patch.tif (bbox [26,40]→[32,46])
# Saved kiln_3956_patch.tif (bbox [39,6]→[45,12])
# Saved kiln_3957_patch.tif (bbox [39,6]→[45,12])
# Saved kiln_3958_patch.tif (bbox [37,36]→[43,42])
# Saved kiln_3959_patch.tif (bbox [37,36]→[43,42])
# Saved kiln_3960_patch.tif (bbox [38,19]→[44,25])
# Saved kiln_3961_patch.tif (bbox [38,19]→[44,25])
# Saved kiln_3962_patch.tif (bbox [1,57]→[7,63])
# Saved kiln_3963_patch.tif (bbox [1,57]→[7,63])
# Saved kiln_3964_patch.tif (bbox [18,57]→[24,63])
# Saved kiln_3965_patch.tif (bbox [18,57]→[24,63])
# Saved kiln_3966_patch.tif (bbox [10,18]→[16,24])
# Saved kiln_3967_patch.tif (bbox [10,18]→[16,24])
# Saved kiln_3968_patch.tif (bbox [55,53]→[61,59])
# Saved kiln_3969_patch.tif (bbox [55,53]→[61,59])
# Saved kiln_3970_patch.tif (bbox [43,48]→[49,54])
# Saved kiln_3971_patch.tif (bbox [43,48]→[49,54])
# Saved kiln_3972_patch.tif (bbox [32,32]→[38,38])
# Saved kiln_3973_patch.tif (bbox [32,32]→[38,38])
# Saved kiln_3974_patch.tif (bbox [38,29]→[44,35])
# Saved kiln_3975_patch.tif (bbox [38,29]→[44,35])
# Saved kiln_3976_patch.tif (bbox [8,55]→[14,61])
# Saved kiln_3977_patch.tif (bbox [8,55]→[14,61])
# Saved kiln_3978_patch.tif (bbox [0,13]→[3,19])
# Saved kiln_3979_patch.tif (bbox [0,13]→[3,19])
# Saved kiln_3980_patch.tif (bbox [1,16]→[7,22])
# Saved kiln_3981_patch.tif (bbox [1,16]→[7,22])
# Saved kiln_3982_patch.tif (bbox [19,36]→[25,42])
# Saved kiln_3983_patch.tif (bbox [19,36]→[25,42])
# Saved kiln_3984_patch.tif (bbox [50,44]→[56,50])
# Saved kiln_3985_patch.tif (bbox [50,44]→[56,50])
# Saved kiln_3986_patch.tif (bbox [29,12]→[35,18])
# Saved kiln_3987_patch.tif (bbox [29,12]→[35,18])
# Saved kiln_3988_patch.tif (bbox [56,47]→[62,53])
# Saved kiln_3989_patch.tif (bbox [56,47]→[62,53])
# Saved kiln_3990_patch.tif (bbox [14,0]→[20,6])
# Saved kiln_3991_patch.tif (bbox [14,0]→[20,6])
# Saved kiln_3992_patch.tif (bbox [39,43]→[45,49])
# Saved kiln_3993_patch.tif (bbox [39,43]→[45,49])
# Saved kiln_3994_patch.tif (bbox [18,11]→[24,17])
# Saved kiln_3995_patch.tif (bbox [18,11]→[24,17])
# Saved kiln_3996_patch.tif (bbox [44,3]→[50,9])
# Saved kiln_3997_patch.tif (bbox [44,3]→[50,9])
# Saved kiln_3998_patch.tif (bbox [8,1]→[14,7])
# Saved kiln_3999_patch.tif (bbox [8,1]→[14,7])
# Saved kiln_4000_patch.tif (bbox [52,42]→[58,48])
# Saved kiln_4001_patch.tif (bbox [52,42]→[58,48])
# Saved kiln_4002_patch.tif (bbox [29,49]→[35,55])
# Saved kiln_4003_patch.tif (bbox [29,49]→[35,55])
# Saved kiln_4004_patch.tif (bbox [38,42]→[44,48])
# Saved kiln_4005_patch.tif (bbox [38,42]→[44,48])
# Saved kiln_4006_patch.tif (bbox [59,1]→[63,7])
# Saved kiln_4007_patch.tif (bbox [59,1]→[63,7])
# Saved kiln_4008_patch.tif (bbox [35,49]→[41,55])
# Saved kiln_4009_patch.tif (bbox [35,49]→[41,55])
# Saved kiln_4010_patch.tif (bbox [9,46]→[15,52])
# Saved kiln_4011_patch.tif (bbox [9,46]→[15,52])
# Saved kiln_4012_patch.tif (bbox [7,27]→[13,33])
# Saved kiln_4013_patch.tif (bbox [7,27]→[13,33])
# Saved kiln_4014_patch.tif (bbox [6,13]→[12,19])
# Saved kiln_4015_patch.tif (bbox [6,13]→[12,19])
# Saved kiln_4016_patch.tif (bbox [15,24]→[21,30])
# Saved kiln_4017_patch.tif (bbox [15,24]→[21,30])
# Saved kiln_4018_patch.tif (bbox [60,37]→[63,43])
# Saved kiln_4019_patch.tif (bbox [60,37]→[63,43])
# Saved kiln_4020_patch.tif (bbox [54,39]→[60,45])
# Saved kiln_4021_patch.tif (bbox [54,39]→[60,45])
# Saved kiln_4022_patch.tif (bbox [41,29]→[47,35])
# Saved kiln_4023_patch.tif (bbox [41,29]→[47,35])
# Saved kiln_4024_patch.tif (bbox [1,54]→[7,60])
# Saved kiln_4025_patch.tif (bbox [1,54]→[7,60])
# Saved kiln_4026_patch.tif (bbox [55,14]→[61,20])
# Saved kiln_4027_patch.tif (bbox [55,14]→[61,20])
# Saved kiln_4028_patch.tif (bbox [24,36]→[30,42])
# Saved kiln_4029_patch.tif (bbox [24,36]→[30,42])
# Saved kiln_4030_patch.tif (bbox [35,34]→[41,40])
# Saved kiln_4031_patch.tif (bbox [35,34]→[41,40])
# Saved kiln_4032_patch.tif (bbox [4,31]→[10,37])
# Saved kiln_4033_patch.tif (bbox [4,31]→[10,37])
# Saved kiln_4034_patch.tif (bbox [28,3]→[34,9])
# Saved kiln_4035_patch.tif (bbox [28,3]→[34,9])
# Saved kiln_4036_patch.tif (bbox [60,6]→[63,12])
# Saved kiln_4037_patch.tif (bbox [60,6]→[63,12])
# Saved kiln_4038_patch.tif (bbox [19,45]→[25,51])
# Saved kiln_4039_patch.tif (bbox [19,45]→[25,51])
# Saved kiln_4040_patch.tif (bbox [0,38]→[6,44])
# Saved kiln_4041_patch.tif (bbox [0,38]→[6,44])
# Saved kiln_4042_patch.tif (bbox [27,44]→[33,50])
# Saved kiln_4043_patch.tif (bbox [27,44]→[33,50])
# Saved kiln_4044_patch.tif (bbox [42,46]→[48,52])
# Saved kiln_4045_patch.tif (bbox [42,46]→[48,52])
# Saved kiln_4046_patch.tif (bbox [11,40]→[17,46])
# Saved kiln_4047_patch.tif (bbox [11,40]→[17,46])
# Saved kiln_4048_patch.tif (bbox [12,48]→[18,54])
# Saved background_0001_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0002_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0003_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0004_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0005_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0006_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0007_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0008_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0009_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0010_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0011_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0012_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0013_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0014_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0015_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0016_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0017_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0018_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0019_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0020_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0021_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0022_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0023_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0024_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0025_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0026_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0027_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0028_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_0029_patch.tif (bbox [ ][ ]→[ ][ ])
# ...
# Saved background_3749_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3750_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3751_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3752_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3753_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3754_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3755_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3756_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3757_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3758_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3759_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3760_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3761_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3762_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3763_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3764_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3765_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3766_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3767_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3768_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3769_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3770_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3771_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3772_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3773_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3774_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3775_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3776_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3777_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3778_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3779_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3780_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3781_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3782_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3783_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3784_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3785_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3786_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3787_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3788_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3789_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3790_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3791_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3792_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3793_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3794_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3795_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3796_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3797_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3798_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3799_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3800_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3801_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3802_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3803_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3804_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3805_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3806_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3807_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3808_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3809_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3810_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3811_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3812_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3813_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3814_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3815_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3816_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3817_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3818_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3819_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3820_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3821_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3822_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3823_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3824_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3825_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3826_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3827_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3828_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3829_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3830_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3831_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3832_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3833_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3834_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3835_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3836_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3837_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3838_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3839_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3840_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3841_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3842_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3843_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3844_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3845_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3846_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3847_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3848_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3849_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3850_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3851_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3852_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3853_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3854_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3855_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3856_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3857_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3858_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3859_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3860_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3861_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3862_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3863_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3864_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3865_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3866_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3867_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3868_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3869_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3870_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3871_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3872_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3873_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3874_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3875_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3876_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3877_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3878_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3879_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3880_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3881_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3882_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3883_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3884_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3885_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3886_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3887_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3888_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3889_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3890_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3891_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3892_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3893_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3894_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3895_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3896_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3897_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3898_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3899_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3900_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3901_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3902_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3903_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3904_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3905_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3906_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3907_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3908_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3909_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3910_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3911_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3912_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3913_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3914_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3915_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3916_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3917_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3918_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3919_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3920_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3921_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3922_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3923_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3924_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3925_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3926_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3927_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3928_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3929_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3930_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3931_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3932_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3933_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3934_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3935_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3936_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3937_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3938_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3939_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3940_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3941_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3942_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3943_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3944_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3945_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3946_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3947_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3948_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3949_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3950_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3951_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3952_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3953_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3954_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3955_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3956_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3957_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3958_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3959_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3960_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3961_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3962_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3963_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3964_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3965_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3966_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3967_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3968_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3969_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3970_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3971_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3972_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3973_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3974_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3975_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3976_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3977_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3978_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3979_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3980_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3981_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3982_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3983_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3984_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3985_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3986_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3987_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3988_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3989_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3990_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3991_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3992_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3993_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3994_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3995_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3996_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3997_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3998_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_3999_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4000_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4001_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4002_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4003_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4004_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4005_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4006_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4007_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4008_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4009_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4010_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4011_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4012_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4013_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4014_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4015_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4016_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4017_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4018_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4019_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4020_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4021_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4022_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4023_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4024_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4025_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4026_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4027_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4028_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4029_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4030_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4031_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4032_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4033_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4034_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4035_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4036_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4037_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4038_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4039_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4040_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4041_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4042_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4043_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4044_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4045_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4046_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4047_patch.tif (bbox [ ][ ]→[ ][ ])
# Saved background_4048_patch.tif (bbox [ ][ ]→[ ][ ])
#
# Finished 4048 kiln + 4048 background patches in 269.3s
# Labels saved to kiln_dataset_v2/labels.csv
